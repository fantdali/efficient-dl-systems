# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"

# %%
# !torchrun --nproc_per_node 3 sequential_print.py
# Out:
# Process 0
# Process 1
# Process 2
# Process 2
# Process 1
# Process 0
# ---
# Process 0
# Process 1
# Process 2
# Process 2
# Process 1
# Process 0
# ---
# Process 0
# Process 1
# Process 2
# Process 2
# Process 1
# Process 0

# %%
# !pytest test_syncbn.py -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.20, pytest-8.3.4, pluggy-1.6.0 -- /home/dali/prsnl/efficient-dl-systems/week03_data_parallel/homework/.venv/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/dali/prsnl/efficient-dl-systems/week03_data_parallel/homework
# collecting ...
# collected 16 items
#
# test_syncbn.py::test_batchnorm[32-128-1] PASSED                          [  6%]
# test_syncbn.py::test_batchnorm[32-128-4] PASSED                          [ 12%]
# test_syncbn.py::test_batchnorm[32-256-1] PASSED                          [ 18%]
# test_syncbn.py::test_batchnorm[32-256-4] PASSED                          [ 25%]
# test_syncbn.py::test_batchnorm[32-512-1] PASSED                          [ 31%]
# test_syncbn.py::test_batchnorm[32-512-4] PASSED                          [ 37%]
# test_syncbn.py::test_batchnorm[32-1024-1] PASSED                         [ 43%]
# ...

# %%
# !nvidia-smi
# Out:
# Sun Mar 22 19:41:11 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.126.09             Driver Version: 580.126.09     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...    Off |   00000000:01:00.0  On |                  N/A |
# | N/A   39C    P8             14W /  115W |     167MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !python bench_syncbn.py
# Out:
# Device: cuda, Workers: 1
#
# impl     | hid_dim | batch |  time_ms |   mem_MB
# --------------------------------------------------
# torch    |     512 |    32 |    0.219 |      0.3
# torch    |     512 |    64 |    0.207 |      0.5
# torch    |    1024 |    32 |    0.197 |      0.6
# torch    |    1024 |    64 |    0.218 |      1.1
# custom   |     512 |    32 |    0.433 |      0.4
# custom   |     512 |    64 |    0.420 |      0.8
# custom   |    1024 |    32 |    0.404 |      0.8
# custom   |    1024 |    64 |    0.409 |      1.6

# %%
# !torchrun --nproc_per_node 1 torch_ddp_cifar100.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0: train_loss=0.0714, train_acc=0.0269, val_loss=4.3539, val_acc=0.0700, time=10.15s
# Epoch 1: train_loss=0.0687, train_acc=0.0484, val_loss=4.2464, val_acc=0.0953, time=9.72s
# Epoch 2: train_loss=0.0673, train_acc=0.0650, val_loss=4.1792, val_acc=0.1187, time=10.18s
# Epoch 3: train_loss=0.0661, train_acc=0.0798, val_loss=4.1043, val_acc=0.1292, time=9.61s
# Epoch 4: train_loss=0.0652, train_acc=0.0926, val_loss=4.0379, val_acc=0.1418, time=9.78s
#
# === Torch DDP Benchmark Summary ===
# Total training time: 49.43s
# Avg epoch time:      9.89s
# Peak GPU memory:     67.7 MB
# Final val_acc:       0.1418

# %%
# !torchrun --nproc_per_node 1 custom_ddp_cifar100.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0: train_loss=0.0714, train_acc=0.0268, val_loss=4.3519, val_acc=0.0694, time=9.86s
# Epoch 1: train_loss=0.0687, train_acc=0.0480, val_loss=4.2440, val_acc=0.0952, time=9.58s
# Epoch 2: train_loss=0.0673, train_acc=0.0649, val_loss=4.1761, val_acc=0.1174, time=9.61s
# Epoch 3: train_loss=0.0661, train_acc=0.0799, val_loss=4.1008, val_acc=0.1287, time=9.70s
# Epoch 4: train_loss=0.0652, train_acc=0.0924, val_loss=4.0339, val_acc=0.1421, time=9.58s
#
# === Custom DDP Benchmark Summary ===
# Total training time: 48.32s
# Avg epoch time:      9.66s
# Peak GPU memory:     63.7 MB
# Final val_acc:       0.1421

# %%
# !nvidia-smi
# Out:
# Sun Mar 22 17:08:57 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.57.01              Driver Version: 565.57.01      CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4090        On  |   00000000:24:00.0 Off |                  Off |
# |  0%   33C    P8             27W /  450W |       2MiB /  24564MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch
print(torch.__version__)
torch.cuda.device_count()
# Out:
# 2.4.0+cu121
# 2

# %%
# !python bench_syncbn.py
# Out:
# Device: cuda, Workers: 2
#
# impl     | hid_dim | batch |  time_ms |   mem_MB
# --------------------------------------------------
# torch    |     512 |    32 |    1.233 |      0.2
# torch    |     512 |    64 |    1.217 |      0.3
# torch    |    1024 |    32 |    1.059 |      0.4
# torch    |    1024 |    64 |    1.248 |      0.7
# custom   |     512 |    32 |    1.221 |      0.2
# custom   |     512 |    64 |    1.205 |      0.4
# custom   |    1024 |    32 |    1.244 |      0.4
# custom   |    1024 |    64 |    1.198 |      0.8

# %%
# !torchrun --nproc_per_node 2 torch_ddp_cifar100.py
# Out:
# W0322 17:13:42.704000 131914915553280 torch/distributed/run.py:779]
# W0322 17:13:42.704000 131914915553280 torch/distributed/run.py:779] *****************************************
# W0322 17:13:42.704000 131914915553280 torch/distributed/run.py:779] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0322 17:13:42.704000 131914915553280 torch/distributed/run.py:779] *****************************************
# ...
# 100.0%
# Extracting ./cifar/cifar-100-python.tar.gz to ./cifar
# /root/efficient-dl-systems/week03_data_parallel/homework/.venv/lib/python3.11/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# ...

# %%
# !torchrun --nproc_per_node 2 custom_ddp_cifar100.py
# Out:
# W0322 17:15:44.674000 127670715121664 torch/distributed/run.py:779]
# W0322 17:15:44.674000 127670715121664 torch/distributed/run.py:779] *****************************************
# W0322 17:15:44.674000 127670715121664 torch/distributed/run.py:779] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0322 17:15:44.674000 127670715121664 torch/distributed/run.py:779] *****************************************
# Files already downloaded and verified
# /root/efficient-dl-systems/week03_data_parallel/homework/.venv/lib/python3.11/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# ...
